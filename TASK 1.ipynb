# %%
# s = "this is My First Python programming class and i am learNING python string and its function"
# 1 . Try to extract data from index one to index 300 with a jump of 3 
# 2. Try to reverse a string without using reverse function 
# 3. Try to split a string after conversion of entire string in uppercase 
# 4. try to convert the whole string into lower case 
# 5 . Try to capitalize the whole string 
# 6 . Write a diference between isalnum() and isalpha()
# 7. Try to give an example of expand tab
# 8 . Give an example of strip , lstrip and rstrip 
# 9.  Replace a string charecter by another charector by taking your own example 
# "sudhanshu"
# 10 . Try  to give a defination of string center function with and exmple 
# 11 . Write your own definition of compiler and interpretor without copy paste form internet in your own language
# 12 . Python is a interpreted of compiled language give a clear ans with your understanding 
# 13 . Try to write a usecase of python with your understanding .


# you have to send a jupyter notebook to shivan@ineuron.ai before next saturday class 21st of may .

# %%
s = "this is My First Python programming class and i am learNING python string and its function"

# %% [markdown]
# #### Q.1. Try to extract data from index one to index 300 with a jump of 3

# %%
s[0:300:3]
# Out:
# 'tssyityopgmncsa alrNph rgni ni'

# %% [markdown]
# #### Q.2.Try to reverse a string without using reverse function

# %%
s[::-1]
# Out:
# 'noitcnuf sti dna gnirts nohtyp GNINrael ma i dna ssalc gnimmargorp nohtyP tsriF yM si siht'

# %% [markdown]
# #### Q.3. Try to split a string after conversion of entire string in uppercase

# %%
s = s.upper()
s.split()
# Out:
# ['THIS',
#  'IS',
#  'MY',
#  'FIRST',
#  'PYTHON',
#  'PROGRAMMING',
#  'CLASS',
#  'AND',
#  'I',
#  'AM',
#  'LEARNING',
#  'PYTHON',
#  'STRING',
#  'AND',
#  'ITS',
#  'FUNCTION']

# %% [markdown]
# #### Q.4.  try to convert the whole string into lower case

# %%
s.lower()
# Out:
# 'this is my first python programming class and i am learning python string and its function'

# %% [markdown]
# #### Q.5. Try to capitalize the whole string

# %%
s.capitalize()
# Out:
# 'This is my first python programming class and i am learning python string and its function'

# %% [markdown]
# #### Q.6.  Write a diference between isalnum() and isalpha()

# %%
# isalnum() - this function checks both alpha and numerica character from string
# isalpha() - Thsi function checks only aplhabetical character from string

# %% [markdown]
# #### Q.7. Try to give an example of expand tab

# %%
a = "Gaurav\tPrashant\tPatil"

# %%
a.expandtabs()
# Out:
# 'Gaurav  Prashant        Patil'

# %% [markdown]
# #### Q.8. Give an example of strip , lstrip and rstrip

# %%
s = "  Abra ka Dabra  "

# %%
s.strip()
# Out:
# 'Abra ka Dabra'

# %%
s.rstrip()
# Out:
# '  Abra ka Dabra'

# %%
s.lstrip()
# Out:
# 'Abra ka Dabra  '

# %% [markdown]
# #### Q.9. Replace a string charecter by another charector by taking your own example
#  "sudhanshu"

# %%
b = "allu arjun"
b
# Out:
# 'allu arjun'

# %%
b.replace("a","b")
# Out:
# 'bllu brjun'

# %% [markdown]
# #### Q.10. Try  to give a defination of string center function with and exmple

# %%
# def. of string center - we can defjne our string in centre with whaterver width we want and this width empty spaces can filled by special characters or alphnumeric characters.
b.center(25,"@")
# Out:
# '@@@@@@@@allu arjun@@@@@@@'

# %% [markdown]
# ### Q.11.  Write your own definition of compiler and interpretor without copy paste form internet in your own language

# %% [markdown]
# ##### Compiler - Main use of compiler is convert the our language into a machine language which is binary. simply we can say conversion of characters in binary responses.
# ##### Interpreter - interpreter is running a code single line at a time. Interpreter languages slow as compare to compiled languages.

# %% [markdown]
# ### Q.12. Python is a interpreted of compiled language give a clear ans with your understanding

# %%
# Python programme can be executed as either a compiled program or as an interpreted language in interactive mode.

# %% [markdown]
# ### Q.13. Try to write a usecase of python with your understanding .

# %%
# 1. Backend Development.
# 2. Data Science and Machine Learning.
# 3. It is used in IOT.
# 4. It is easy to learn because of we can write a programmes in simple english.
# 5. It is used for Deep Learning and AI.
